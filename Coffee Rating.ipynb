# %% [markdown]
# https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-07-07/readme.md

# %%
# Get the Data

# Read in with tidytuesdayR package 
# Install from CRAN via: install.packages("tidytuesdayR")
# This loads the readme and all the datasets for the week of interest
install.packages("tidytuesdayR")
# Either ISO-8601 date or year/week works!

tuesdata <- tidytuesdayR::tt_load('2020-07-07')
tuesdata <- tidytuesdayR::tt_load(2020, week = 28)

coffee_ratings <- tuesdata$coffee_ratings

# Or read in the data manually

coffee_ratings <- readr::read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-07-07/coffee_ratings.csv')
# Out:
# package 'tidytuesdayR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Shadow\AppData\Local\Temp\RtmpMZceEM\downloaded_packages
# Error in loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]]): namespace 'rlang' 0.3.4 is already loaded, but >= 0.4.3 is required
# Traceback:
#
# 1. tidytuesdayR::tt_load
# 2. getExportedValue(pkg, name)
# 3. asNamespace(ns)
# 4. getNamespace(ns)
# 5. loadNamespace(name)
# 6. namespaceImportFrom(ns, loadNamespace(j <- i[[1L]], c(lib.loc,
#  .     .libPaths()), versionCheck = vI[[j]]), i[[2L]], from = package)
# 7. asNamespace(ns)
# 8. loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]])
# 9. namespaceImport(ns, loadNamespace(i, c(lib.loc, .libPaths()),
#  .     versionCheck = vI[[i]]), from = package)
# 10. loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]])
# 11. stop(gettextf("namespace %s %s is already loaded, but %s %s is required",
#   .     sQuote(package), current, zop, zversion), domain = NA)

# %%
require(devtools)
#install.packages("janitor")
#install.packages("tidyselect")
install_version("tidyselect")
# Out:
# Loading required package: devtools
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# "there is no package called 'devtools'"
# Error in install_version("tidyselect"): could not find function "install_version"
# Traceback:

# %%
library(tidyverse)
#library(janitor)

raw_arabica <- read_csv("https://raw.githubusercontent.com/jldbc/coffee-quality-database/master/data/arabica_data_cleaned.csv")# %>% 
#  janitor::clean_names()

raw_robusta <- read_csv("https://raw.githubusercontent.com/jldbc/coffee-quality-database/master/data/robusta_data_cleaned.csv")#,

#        col_types = cols(
#                          X1 = col_double(),
##                          Species = col_character(),
#                          Owner = col_character(),
#                          Country.of.Origin = col_character(),
#                          Farm.Name = col_character(),
#                          Lot.Number = col_character(),
#                          Mill = col_character(),
#                          ICO.Number = col_character(),
#                          Company = col_character(),
#                          Altitude = col_character(),
#                          Region = col_character(),
#                          Producer = col_character(),
#                          Number.of.Bags = col_double(),
#                          Bag.Weight = col_character(),
#                          In.Country.Partner = col_character(),
#                          Harvest.Year = col_character(),
#                          Grading.Date = col_character(),
#                          Owner.1 = col_character(),
#                          Variety = col_character(),
#                          Processing.Method = col_character(),
#                          Fragrance...Aroma = col_double(),
#                          Flavor = col_double(),
#                          Aftertaste = col_double(),
#                          Salt...Acid = col_double(),
#                          Balance = col_double(),
#                          Uniform.Cup = col_double(),
#                          Clean.Cup = col_double(),
#                          Bitter...Sweet = col_double(),
#                          Cupper.Points = col_double(),
#                          Total.Cup.Points = col_double(),
#                          Moisture = col_double(),
#                          Category.One.Defects = col_double(),
#                          Quakers = col_double(),
#                          Color = col_character(),
#                          Category.Two.Defects = col_double(),
#                          Expiration = col_character(),
#                          Certification.Body = col_character(),
#                          Certification.Address = col_character(),
#                          Certification.Contact = col_character(),
#                          unit_of_measurement = col_character(),
#                          altitude_low_meters = col_double(),
#                          altitude_high_meters = col_double(),
#                          altitude_mean_meters = col_double()
#                        ))  #%>% #  janitor::clean_names() %>% 
#  rename(acidity = salt_acid, sweetness = bitter_sweet,
#         aroma = fragrance_aroma, body = mouthfeel,uniformity = uniform_cup)


#all_ratings <- bind_rows(raw_arabica, raw_robusta) %>% 
#  select(-x1) %>% 
#  select(total_cup_points, species, everything())

#all_ratings %>% 
#  skimr::skim()

#all_ratings %>% 
#  write_csv("2020/2020-07-07/coffee_ratings.csv")
# Out:
# Warning message:
# "Missing column names filled in: 'X1' [1]"Parsed with column specification:
# cols(
#   .default = col_character(),
#   X1 = col_double(),
#   Number.of.Bags = col_double(),
#   Aroma = col_double(),
#   Flavor = col_double(),
#   Aftertaste = col_double(),
#   Acidity = col_double(),
#   Body = col_double(),
#   Balance = col_double(),
#   Uniformity = col_double(),
#   Clean.Cup = col_double(),
#   Sweetness = col_double(),
#   Cupper.Points = col_double(),
#   Total.Cup.Points = col_double(),
#   Moisture = col_double(),
#   Category.One.Defects = col_double(),
#   Quakers = col_double(),
#   Category.Two.Defects = col_double(),
#   altitude_low_meters = col_double(),
#   altitude_high_meters = col_double(),
#   altitude_mean_meters = col_double()
# )
# See spec(...) for full column specifications.
# Warning message:
# "Missing column names filled in: 'X1' [1]"Parsed with column specification:
# cols(
#   .default = col_character(),
#   X1 = col_double(),
#   Number.of.Bags = col_double(),
#   Harvest.Year = col_double(),
#   Fragrance...Aroma = col_double(),
#   Flavor = col_double(),
#   Aftertaste = col_double(),
#   Salt...Acid = col_double(),
#   Bitter...Sweet = col_double(),
#   Mouthfeel = col_double(),
#   Uniform.Cup = col_double(),
#   Clean.Cup = col_double(),
#   Balance = col_double(),
#   Cupper.Points = col_double(),
#   Total.Cup.Points = col_double(),
#   Moisture = col_double(),
#   Category.One.Defects = col_double(),
#   Quakers = col_double(),
#   Category.Two.Defects = col_double(),
#   altitude_low_meters = col_double(),
#   altitude_high_meters = col_double()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.

# %%
raw_arabica <- read_csv("https://raw.githubusercontent.com/jldbc/coffee-quality-database/master/data/arabica_data_cleaned.csv") 
raw_robusta <- read_csv("https://raw.githubusercontent.com/jldbc/coffee-quality-database/master/data/robusta_data_cleaned.csv")
# Out:
# Warning message:
# "Missing column names filled in: 'X1' [1]"Parsed with column specification:
# cols(
#   .default = col_character(),
#   X1 = col_double(),
#   Number.of.Bags = col_double(),
#   Aroma = col_double(),
#   Flavor = col_double(),
#   Aftertaste = col_double(),
#   Acidity = col_double(),
#   Body = col_double(),
#   Balance = col_double(),
#   Uniformity = col_double(),
#   Clean.Cup = col_double(),
#   Sweetness = col_double(),
#   Cupper.Points = col_double(),
#   Total.Cup.Points = col_double(),
#   Moisture = col_double(),
#   Category.One.Defects = col_double(),
#   Quakers = col_double(),
#   Category.Two.Defects = col_double(),
#   altitude_low_meters = col_double(),
#   altitude_high_meters = col_double(),
#   altitude_mean_meters = col_double()
# )
# See spec(...) for full column specifications.
# Warning message:
# "Missing column names filled in: 'X1' [1]"Parsed with column specification:
# cols(
#   .default = col_character(),
#   X1 = col_double(),
#   Number.of.Bags = col_double(),
#   Harvest.Year = col_double(),
#   Fragrance...Aroma = col_double(),
#   Flavor = col_double(),
#   Aftertaste = col_double(),
#   Salt...Acid = col_double(),
#   Bitter...Sweet = col_double(),
#   Mouthfeel = col_double(),
#   Uniform.Cup = col_double(),
#   Clean.Cup = col_double(),
#   Balance = col_double(),
#   Cupper.Points = col_double(),
#   Total.Cup.Points = col_double(),
#   Moisture = col_double(),
#   Category.One.Defects = col_double(),
#   Quakers = col_double(),
#   Category.Two.Defects = col_double(),
#   altitude_low_meters = col_double(),
#   altitude_high_meters = col_double()
#   # ... with 1 more columns
# )
# See spec(...) for full column specifications.

# %%
raw_robusta %>% arrange(desc(Total.Cup.Points))
# Out:
#    X1 Species Owner                             Country.of.Origin
# 1   1 Robusta ankole coffee producers coop      Uganda
# 2   2 Robusta nishant gurjer                    India
# 3   3 Robusta andrew hetzel                     India
# 4   4 Robusta ugacof                            Uganda
# 5   5 Robusta katuka development trust ltd      Uganda
# 6   6 Robusta andrew hetzel                     India
# 7   7 Robusta andrew hetzel                     India
# 8   8 Robusta nishant gurjer                    India
# 9   9 Robusta nishant gurjer                    India
# 10 10 Robusta ugacof                            Uganda
# 11 11 Robusta ugacof                            Uganda
# 12 12 Robusta nishant gurjer                    India
# 13 13 Robusta andrew hetzel                     India
# 14 14 Robusta kasozi coffee farmers association Uganda
# 15 15 Robusta ankole coffee producers coop      Uganda
# 16 16 Robusta andrew hetzel                     India
# 17 17 Robusta andrew hetzel                     India
# 18 18 Robusta kawacom uganda ltd                Uganda
# 19 19 Robusta nitubaasa ltd                     Uganda
# 20 20 Robusta mannya coffee project             Uganda
# 21 21 Robusta andrew hetzel                     India
# 22 22 Robusta andrew hetzel                     India
# 23 23 Robusta andrew hetzel                     United States
# 24 24 Robusta luis robles                       Ecuador
# 25 25 Robusta luis robles                       Ecuador
# 26 26 Robusta james moore                       United States
# 27 27 Robusta cafe politico                     India
# 28 28 Robusta cafe politico                     Vietnam
#    Farm.Name                          Lot.Number
# 1  kyangundu cooperative society      NA
# 2  sethuraman estate kaapi royale     25
# 3  sethuraman estate                  NA
# 4  ugacof project area                NA
# 5  katikamu capca farmers association NA
# 6  NA                                 NA
# 7  sethuraman estates                 NA
# 8  sethuraman estate kaapi royale     7
# 9  sethuraman estate                  RKR
# 10 ishaka                             NA
# 11 ugacof project area                NA
# 12 sethuraman estate kaapi royale     RC AB
# 13 sethuraman estates                 NA
# 14 kasozi coffee farmers              NA
# 15 kyangundu coop society             NA
# 16 sethuraman estate                  NA
# 17 sethuraman estates                 NA
# 18 bushenyi                           NA
# 19 kigezi coffee farmers association  NA
# 20 mannya coffee project              NA
# 21 sethuraman estates                 NA
# 22 sethuraman estates                 NA
# 23 sethuraman estates                 NA
# 24 robustasa                          Lavado 1
# 25 robustasa                          Lavado 3
# 26 fazenda cazengo                    NA
# 27 NA                                 NA
# 28 NA                                 NA
#    Mill                                   ICO.Number
# 1  ankole coffee producers                0
# 2  sethuraman estate                      14/1148/2017/21
# 3  NA                                     0000
# 4  ugacof                                 0
# 5  katuka development trust               0
# 6  (self)                                 NA
# 7  NA                                     NA
# 8  sethuraman estate                      14/1148/2017/18
# 9  sethuraman estate                      14/1148/2016/17
# 10 nsubuga umar                           0
# 11 ugacof                                 0
# 12 sethuraman estate                      14/1148/2016/12
# 13 NA                                     NA
# 14 NA                                     0
# 15 ankole coffee producers coop union ltd 0
# 16 NA                                     0000
# 17 sethuraman estates                     NA
# 18 kawacom                                0
# 19 nitubaasa                              0
# 20 mannya coffee project                  0
# 21 NA                                     NA
# 22 sethuraman estates                     NA
# 23 sethuraman estates                     n/a
# 24 our own lab                            NA
# 25 own laboratory                         NA
# 26 cafe cazengo                           NA
# 27 NA                                     14-1118-2014-0087
# 28 NA                                     n/a
#    Company                           Altitude   ... Color
# 1  ankole coffee producers coop      1488       ... Green
# 2  kaapi royale                      3170       ... NA
# 3  sethuraman estate                 1000m      ... Green
# 4  ugacof ltd                        1212       ... Green
# 5  katuka development trust ltd      1200-1300  ... Green
# 6  cafemakers, llc                   3000'      ... Green
# 7  cafemakers                        750m       ... Green
# 8  kaapi royale                      3140       ... Bluish-Green
# 9  kaapi royale                      1000       ... Green
# 10 ugacof ltd                        900-1300   ... Green
# 11 ugacof ltd                        1095       ... Green
# 12 kaapi royale                      1000       ... Green
# 13 cafemakers                        750m       ... Green
# 14 kasozi coffee farmers association 1367       ... Green
# 15 ankole coffee producers coop      1488       ... Green
# 16 sethuraman estate                 1000m      ... Green
# 17 cafemakers, llc                   750m       ... Blue-Green
# 18 kawacom uganda ltd                1600       ... Green
# 19 nitubaasa ltd                     1745       ... Green
# 20 mannya coffee project             1200       ... Green
# 21 cafemakers                        750m       ... Bluish-Green
# 22 cafemakers, llc                   750m       ... Green
# 23 cafemakers, llc                   3000'      ... Green
# 24 robustasa                         NA         ... Blue-Green
# 25 robustasa                         40         ... Blue-Green
# 26 global opportunity fund           795 meters ... NA
# 27 cafe politico                     NA         ... Green
# 28 cafe politico                     NA         ... None
#    Category.Two.Defects Expiration          Certification.Body
# 1  2                    June 26th, 2015     Uganda Coffee Development Authority
# 2  2                    October 31st, 2018  Specialty Coffee Association
# 3  0                    April 29th, 2016    Specialty Coffee Association
# 4  7                    July 14th, 2015     Uganda Coffee Development Authority
# 5  3                    June 26th, 2015     Uganda Coffee Development Authority
# 6  0                    February 28th, 2013 Specialty Coffee Association
# 7  0                    May 15th, 2015      Specialty Coffee Association
# 8  0                    October 25th, 2018  Specialty Coffee Association
# 9  0                    August 17th, 2017   Specialty Coffee Association
# 10 6                    August 5th, 2015    Uganda Coffee Development Authority
# 11 1                    June 26th, 2015     Uganda Coffee Development Authority
# 12 0                    August 23rd, 2017   Specialty Coffee Association
# 13 1                    May 19th, 2015      Specialty Coffee Association
# 14 7                    July 14th, 2015     Uganda Coffee Development Authority
# 15 2                    July 14th, 2015     Uganda Coffee Development Authority
# 16 0                    April 29th, 2016    Specialty Coffee Association
# 17 0                    June 3rd, 2014      Specialty Coffee Association
# 18 1                    June 27th, 2015     Uganda Coffee Development Authority
# 19 2                    June 27th, 2015     Uganda Coffee Development Authority
# 20 1                    June 27th, 2015     Uganda Coffee Development Authority
# 21 1                    May 19th, 2015      Specialty Coffee Association
# 22 0                    June 20th, 2014     Specialty Coffee Association
# 23 0                    February 28th, 2013 Specialty Coffee Association
# 24 1                    January 18th, 2017  Specialty Coffee Association
# 25 0                    January 18th, 2017  Specialty Coffee Association
# 26 6                    December 23rd, 2015 Specialty Coffee Association
# 27 1                    August 25th, 2015   Specialty Coffee Association
# 28 9                    August 25th, 2015   Specialty Coffee Association
#    Certification.Address
# 1  e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 2  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 3  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 4  e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 5  e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 6  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 7  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 8  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 9  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 10 e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 11 e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 12 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 13 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 14 e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 15 e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 16 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 17 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 18 e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 19 e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 20 e36d0270932c3b657e96b7b0278dfd85dc0fe743
# 21 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 22 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 23 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 24 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 25 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 26 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 27 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 28 ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#    Certification.Contact                    unit_of_measurement
# 1  03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 2  352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 3  352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 4  03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 5  03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 6  352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 7  352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 8  352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 9  352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 10 03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 11 03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 12 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 13 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 14 03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 15 03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 16 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 17 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 18 03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 19 03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 20 03077a1c6bac60e6f514691634a7f6eb5c85aae8 m
# 21 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 22 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 23 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 24 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 25 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 26 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 27 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
# 28 352d0cf7f3e9be14dad7df644ad65efc27605ae2 m
#    altitude_low_meters altitude_high_meters altitude_mean_meters
# 1  1488                1488                 1488
# 2  3170                3170                 3170
# 3  1000                1000                 1000
# 4  1212                1212                 1212
# 5  1200                1300                 1250
# 6  3000                3000                 3000
# 7   750                 750                  750
# 8  3140                3140                 3140
# 9  1000                1000                 1000
# 10  900                1300                 1100
# 11 1095                1095                 1095
# 12 1000                1000                 1000
# 13  750                 750                  750
# 14 1367                1367                 1367
# 15 1488                1488                 1488
# 16 1000                1000                 1000
# 17  750                 750                  750
# 18 1600                1600                 1600
# 19 1745                1745                 1745
# 20 1200                1200                 1200
# 21  750                 750                  750
# 22  750                 750                  750
# 23 3000                3000                 3000
# 24   NA                  NA                   NA
# 25   40                  40                   40
# 26  795                 795                  795
# 27   NA                  NA                   NA
# 28   NA                  NA                   NA
